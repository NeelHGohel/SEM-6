# %% [markdown]
# <center><h3>10-02-2026</center>
# <center><b><h1>Lab - 11</b></center>
# <pre>

# %% [markdown]
# ## Section 1: PyTorch

# %% [markdown]
# ## Import Torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')


sample_input = torch.randn(1, 10).to(device)
type(sample_input)
# Out:
# Using device: cpu
# torch.Tensor

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)

# %%
# Do for Testing
testing_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)
# Out:
# 60000

# %%
len(testing_data)
# Out:
# 10000

# %%
img,label = training_data[655]

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(),cmap='gray')
plt.title(f"This is a number {label} ")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            nn.Linear(784,128),
            nn.ReLU(),
            nn.Linear(128,10)
        )
    def forward(self,x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
# do for Test_data
test_loader = DataLoader(testing_data,batch_size=64,shuffle=True)

print(len(train_loader),"--",len(test_loader))
# Out:
# 938 -- 157

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train():
    model.train()
    
    num_epochs = 5
    
    for epoch in range(num_epochs):
        print(f"\n--- Epoch {epoch + 1}/{num_epochs} ---")
        
        for batch_No, (data, target) in enumerate(train_loader):
            
            output = model(data)
            
            loss = loss_fn(output, target)
            
            optimizer.zero_grad()  
            loss.backward()        
            optimizer.step()       
            
            if batch_No % 100 == 0:
                print(f"Batch {batch_No}: Loss = {loss.item():.4f}")
        
        print(f"Epoch {epoch + 1} completed!")

# %%
train()
# Out:
# --- Epoch 1/5 ---
# Batch 0: Loss = 2.3233
# Batch 100: Loss = 0.3063
# Batch 200: Loss = 0.5737
# Batch 300: Loss = 0.1706
# Batch 400: Loss = 0.4480
# Batch 500: Loss = 0.1609
# Batch 600: Loss = 0.2784
# Batch 700: Loss = 0.3057
# Batch 800: Loss = 0.5125
# Batch 900: Loss = 0.1191
# Epoch 1 completed!
#
# --- Epoch 2/5 ---
# Batch 0: Loss = 0.3578
# Batch 100: Loss = 0.1468
# Batch 200: Loss = 0.2617
# Batch 300: Loss = 0.2034
# Batch 400: Loss = 0.0909
# Batch 500: Loss = 0.0697
# Batch 600: Loss = 0.0545
# Batch 700: Loss = 0.1686
# Batch 800: Loss = 0.0600
# Batch 900: Loss = 0.2420
# Epoch 2 completed!
#
# --- Epoch 3/5 ---
# Batch 0: Loss = 0.0742
# Batch 100: Loss = 0.0966
# Batch 200: Loss = 0.2156
# Batch 300: Loss = 0.0987
# Batch 400: Loss = 0.2016
# Batch 500: Loss = 0.1602
# Batch 600: Loss = 0.0458
# Batch 700: Loss = 0.0603
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0789
# Epoch 3 completed!
#
# --- Epoch 4/5 ---
# Batch 0: Loss = 0.0451
# Batch 100: Loss = 0.0655
# Batch 200: Loss = 0.1146
# Batch 300: Loss = 0.1866
# Batch 400: Loss = 0.0591
# Batch 500: Loss = 0.0805
# Batch 600: Loss = 0.0396
# Batch 700: Loss = 0.0782
# Batch 800: Loss = 0.0328
# Batch 900: Loss = 0.0530
# Epoch 4 completed!
#
# --- Epoch 5/5 ---
# Batch 0: Loss = 0.1238
# Batch 100: Loss = 0.0591
# Batch 200: Loss = 0.0650
# Batch 300: Loss = 0.1991
# Batch 400: Loss = 0.0987
# Batch 500: Loss = 0.0736
# Batch 600: Loss = 0.0146
# Batch 700: Loss = 0.1417
# Batch 800: Loss = 0.0689
# Batch 900: Loss = 0.1080
# Epoch 5 completed!

# %%
def test():
    model.eval() 
    correct = 0
    
    with torch.no_grad(): 
        for data, target in test_loader:
            output = model(data)
            
            prediction = output.argmax(dim=1) 
            
            correct += (prediction == target).sum().item()

    accuracy = correct / len(test_loader.dataset)
    print(f"Test Accuracy: {accuracy:.1%}")

test()
# Out:
# Test Accuracy: 97.3%
